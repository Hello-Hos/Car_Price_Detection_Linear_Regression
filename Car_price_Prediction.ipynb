# %% [markdown]
# <a href="https://colab.research.google.com/github/Hello-Hos/Car_Price_Detection_Linear_Regression/blob/main/Car_price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# loading the data from CSV file to Pandas DataFrame
car_dataset = pd.read_csv("/content/drive/MyDrive/archive/car_dataset.csv")

# %%
# inspecting the first 5 rows of the dataframe
car_dataset.head()
# Out:
#          ID Levy Manufacturer   Model  Prod_year   Category Leather_interior  \
# 0  44020629    -   VOLKSWAGEN    Golf       2012  Hatchback               No
# 1  45784798    -      HYUNDAI  Sonata       2012      Sedan              Yes
# 2  45800257    -       NISSAN   Tiida       2005      Sedan               No
# 3  45797981  975        VOLVO    XC90       2012       Jeep              Yes
# 4  45814303    -         OPEL   Astra       1993  Hatchback               No
#
#   Fuel_type Engine_volume    Mileage  Cylinders Gear_box_type Drive wheels  \
# 0    Diesel     2.0 Turbo       0 km          4        Manual        Front
# 1    Petrol           2.4   26000 km          4     Tiptronic        Front
# 2    Petrol           1.5  168000 km          4     Automatic        Front
# 3    Petrol           3.2  143000 km          6     Automatic          4x4
# 4    Petrol           1.6  200000 km          4        Manual        Front
#
# ...

# %%
# inspecting the last 5 rows of the dataframe
car_dataset.tail()
# Out:
#             ID  Levy Manufacturer    Model  Prod_year   Category  \
# 8240  44824410  1357         FIAT    Stilo       2004  Universal
# 8241  45682346     -          BMW  528 F10       2012      Sedan
# 8242  45649860  1646        LEXUS   GX 460       2015       Jeep
# 8243  45809706   784       TOYOTA     Aqua       2017  Hatchback
# 8244  45813163   448        HONDA  Insight       2012  Hatchback
#
#      Leather_interior Fuel_type Engine_volume    Mileage  Cylinders  \
# 8240               No    Petrol           1.6  164000 km          4
# 8241              Yes    Petrol     2.8 Turbo  156000 km          4
# 8242              Yes    Petrol           4.6  102907 km          8
# 8243              Yes    Petrol           1.5    3000 km          4
# 8244              Yes    Hybrid           1.3  321269 km          4
#
#      Gear_box_type Drive wheels   Doors       Wheel  Color  Airbags  Price
# 8240        Manual        Front  04-May  Left wheel   Blue        6    NaN
# ...

# %%
# checking the number. of rows and columns
car_dataset.shape
# Out:
# (8245, 18)

# %%
#getting info about dataset
car_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8245 entries, 0 to 8244
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                8245 non-null   int64
#  1   Levy              8245 non-null   object
#  2   Manufacturer      8245 non-null   object
#  3   Model             8245 non-null   object
#  4   Prod_year         8245 non-null   int64
#  5   Category          8245 non-null   object
#  6   Leather_interior  8245 non-null   object
#  7   Fuel_type         8245 non-null   object
#  8   Engine_volume     8245 non-null   object
#  9   Mileage           8245 non-null   object
#  10  Cylinders         8245 non-null   int64
#  11  Gear_box_type     8245 non-null   object
#  12  Drive wheels      8245 non-null   object
#  13  Doors             8245 non-null   object
#  14  Wheel             8245 non-null   object
#  15  Color             8245 non-null   object
# ...

# %%
#checking the no of missing values
car_dataset.isnull().sum()
# Out:
# ID                     0
# Levy                   0
# Manufacturer           0
# Model                  0
# Prod_year              0
# Category               0
# Leather_interior       0
# Fuel_type              0
# Engine_volume          0
# Mileage                0
# Cylinders              0
# Gear_box_type          0
# Drive wheels           0
# Doors                  0
# Wheel                  0
# Color                  0
# Airbags                0
# Price               8245
# dtype: int64

# %%
#checking the distribution of categorical data
print(car_dataset.Fuel_type.value_counts())
print(car_dataset.Gear_box_type.value_counts())
print(car_dataset.Engine_volume.value_counts())
# Out:
# Petrol            4342
# Diesel            1737
# Hybrid            1511
# LPG                415
# CNG                207
# Plug-in Hybrid      32
# Hydrogen             1
# Name: Fuel_type, dtype: int64
# Automatic    5782
# Tiptronic    1361
# Manual        800
# Variator      302
# Name: Gear_box_type, dtype: int64
# 2            1671
# 2.5           923
# 1.8           766
# 1.6           601
# 1.5           546
#              ...
# 4.2 Turbo       1
# 3.7 Turbo       1
# 4.8 Turbo       1
# 10.8            1
# 2.6 Turbo       1
# Name: Engine_volume, Length: 97, dtype: int64

# %% [markdown]
# **Encoding the categorical data**

# %%
#encoding 'Fuel_type' column
car_dataset.replace({'Fuel_type':{'Petrol': 0, 'Diesel' : 1 , 'CNG' : 2 , 'LPG': 3, 'Hybrid' : 4, 'Plug-in Hybrid': 5,'Hydrogen': 6}},inplace=True)

# %%
#encoding 'Gear_box_type' column
car_dataset.replace({'Gear_box_type':{'Automatic': 0, 'Manual': 1,'Tiptronic': 2 }},inplace=True)

# %%
car_dataset.head()
# Out:
#          ID Levy Manufacturer   Model  Prod_year   Category Leather_interior  \
# 0  44020629    -   VOLKSWAGEN    Golf       2012  Hatchback               No
# 1  45784798    -      HYUNDAI  Sonata       2012      Sedan              Yes
# 2  45800257    -       NISSAN   Tiida       2005      Sedan               No
# 3  45797981  975        VOLVO    XC90       2012       Jeep              Yes
# 4  45814303    -         OPEL   Astra       1993  Hatchback               No
#
#   Fuel_type Engine_volume    Mileage  Cylinders Gear_box_type Drive wheels  \
# 0    Diesel     2.0 Turbo       0 km          4        Manual        Front
# 1    Petrol           2.4   26000 km          4     Tiptronic        Front
# 2    Petrol           1.5  168000 km          4     Automatic        Front
# 3    Petrol           3.2  143000 km          6     Automatic          4x4
# 4    Petrol           1.6  200000 km          4        Manual        Front
#
# ...

# %% [markdown]
# *Splitting the data and Target*

# %%
X=car_dataset.drop(['ID', 'Airbags'],axis=1)
Y=car_dataset['Airbags']

# %%
print(X)
# Out:
#             ID  Levy Manufacturer    Model  Prod_year   Category  \
# 0     44020629     -   VOLKSWAGEN     Golf       2012  Hatchback
# 1     45784798     -      HYUNDAI   Sonata       2012      Sedan
# 2     45800257     -       NISSAN    Tiida       2005      Sedan
# 3     45797981   975        VOLVO     XC90       2012       Jeep
# 4     45814303     -         OPEL    Astra       1993  Hatchback
# ...        ...   ...          ...      ...        ...        ...
# 8240  44824410  1357         FIAT    Stilo       2004  Universal
# 8241  45682346     -          BMW  528 F10       2012      Sedan
# 8242  45649860  1646        LEXUS   GX 460       2015       Jeep
# 8243  45809706   784       TOYOTA     Aqua       2017  Hatchback
# 8244  45813163   448        HONDA  Insight       2012  Hatchback
#
#      Leather_interior Engine_volume    Mileage  Cylinders Drive wheels  \
# 0                  No     2.0 Turbo       0 km          4        Front
# ...

# %%
print(Y)
# Out:
# 0          Manual
# 1       Tiptronic
# 2       Automatic
# 3       Automatic
# 4          Manual
#           ...
# 8240       Manual
# 8241    Tiptronic
# 8242    Automatic
# 8243    Automatic
# 8244    Automatic
# Name: Gear_box_type, Length: 8245, dtype: object

# %% [markdown]
# **SPLITTING TRAINING AND TEST DATA**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 42)

# %% [markdown]
# Model Training

# %% [markdown]
# 1. Linear Regression

# %%
#Looading the linear regression model
lin_reg_model= LinearRegression()
# Out:
# array(LinearRegression(), dtype=object)

# %%
lin_reg_model.fit(X_train, Y_train)
#pd.to_numeric(df.lin_reg_model, errors="ignore")

# %%
# R Squared error
training_error_score = metrics.r2_score(Y_train, training_data_prediction)
print(training_error_score)
print('R Squared error: {0:.2f} %'.format(training_error_score*100))

# %% [markdown]
# 0.8761249192923511

# %% [markdown]
# R Squared error: 87.61 %

# %% [markdown]
# Visualize the Actual and Predicted Price (based on Training Data)

# %%
plt.scatter(Y_train,training_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price (based on Training Data')
plt.show

# %% [markdown]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 2.  Lasso Regression

# %%
# loading the lasso regression model
lass_reg_model = Lasso()

# %%
lass_reg_model.fit(X_train, Y_train)

# %% [markdown]
# Model Evaluation

# %%
# prediction on Training Data
training_data_prediction = lass_reg_model.predict(X_train)

# %%
# R Squared error
training_error_score = metrics.r2_score(Y_train, training_data_prediction)
print('R Squared error: {0:.2f} %'.format(training_error_score*100))

# %% [markdown]
# Visualize the Actual and Predicted Price (based on Training Data)

# %%
plt.scatter(Y_train,training_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price (based on Training Data')
plt.show

# %%
# prediction on Testing Data
test_data_prediction = lass_reg_model.predict(X_test)

# %%
# R Squared error
test_error_score = metrics.r2_score(Y_test, test_data_prediction)
print('R Squared error: {0:.2f} %'.format(test_error_score*100))

# %% [markdown]
# Visualize the Actual and Predicted Price (based on Test Data)

# %%
plt.scatter(Y_test,test_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price (based on Testing Data')
plt.show
